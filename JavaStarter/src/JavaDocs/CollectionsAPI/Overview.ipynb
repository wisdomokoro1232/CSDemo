// %% [markdown]
// - Lists - Ordered Grouping of references where duplicates are allowed
// - Sets- unordered groupings of references, where duplicates are not allowed
// - Maps - key value pairs of objects
//
// - Object references means it doesnt store the actual value but rather the memory location, in a similar way to C. Therefore Primitives cannot be placed in collections only object refernces.
// - This means Wrapper Classes such as Integer (not Int)

// %% [markdown]
// Collections API we shall look at
// - ![image.png](attachment:f5619c29-96f9-449f-a82a-8b8b7387ee3b.png)

// %% [markdown]
// In terms of Sets compared to lists, these can be unordered or unordered but they must not contain duolicates:
// ![image.png](attachment:341de82f-1fec-4516-ad42-dea559e55928.png)
